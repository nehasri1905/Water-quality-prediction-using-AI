# %%
import pandas as pd 
import numpy as n
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d = pd.read_csv('A.csv')
d.head()
# Out:
#    aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65     9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32    21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01    14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36    11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92    24.33     0.03    0.20    0.006        2.67      0.69    0.57
#
#    flouride  bacteria  ...  nitrites  mercury  perchlorate  radium  selenium  \
# 0      0.05      0.20  ...      1.13    0.007        37.75    6.78      0.08
# 1      0.90      0.65  ...      1.93    0.003        32.26    3.21      0.08
# 2      0.99      0.05  ...      1.11    0.006        50.28    7.07      0.07
# 3      1.08      0.71  ...      1.29    0.004         9.12    1.72      0.02
# 4      0.61      0.13  ...      1.11    0.003        16.90    2.41      0.02
#
# ...

# %%
d.columns
# Out:
# Index(['aluminium', 'ammonia', 'arsenic', 'barium', 'cadmium', 'chloramine',
#        'chromium', 'copper', 'flouride', 'bacteria', 'viruses', 'lead',
#        'nitrates', 'nitrites', 'mercury', 'perchlorate', 'radium', 'selenium',
#        'silver', 'uranium', 'Class', 'Ph', 'Turbidity'],
#       dtype='object')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(d['aluminium'],color='red')

plt.subplot(1,2,2)
plt.hist(d['ammonia'],color='blue')
# Out:
# (array([1109.,  732.,  729.,  889.,  745.,  701.,  807.,  795.,  743.,
#          746.]),
#  array([-0.08 ,  2.912,  5.904,  8.896, 11.888, 14.88 , 17.872, 20.864,
#         23.856, 26.848, 29.84 ]),
#  <BarContainer object of 10 artists>)

# %%
d.hist(figsize=(15,55),layout=(15,4), color='red')
plt.show()

# %%
d['arsenic'].hist(figsize=(10,5),color='red')
# Out:
# <AxesSubplot:>

# %%
plt.bar(d['barium'],d['cadmium'], color='red') # scatter, plot, triplot, stackplot
# Out:
# <BarContainer object of 7996 artists>

# %%
plt.boxplot(d['chloramine'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24e3aaea0a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x24e3aaea640>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24e3a6d7d90>],
#  'medians': [<matplotlib.lines.Line2D at 0x24e3aaeabe0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24e3aaeaeb0>],
#  'means': []}

# %%
d['chromium'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.displot(d['copper'], color='red') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot

# %%
sns.residplot(d['perchlorate'],d['arsenic'], color='red') # residplot, scatterplot
# Out:
# C:\Users\SPIRO15\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='perchlorate', ylabel='arsenic'>

# %%
def plot(d, variable):
    dataframe_pie = d[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return n.round(dataframe_pie/d.shape[0]*100,2)

plot(d, 'Class')
# Out:
# 0    88.59
# 1    11.41
# Name: Class, dtype: float64
